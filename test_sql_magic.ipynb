# %% [markdown]
# ### Using SQLMagic to query ADB

# %%
import os
import pandas as pd

from ads.database import connection
from ads.database.connection import Connector

# %%
# memorizzo in un repository locale
# in questo modo nel NB non c'è la pwd
# che ho memorizzato prima nel repo (vedi istruzione commentata)
database_name = "dbtst1_medium"

# connection.update_repository(key=database_name, value=credential)
repo = connection.get_repository(key=database_name)

# import the wallet
wallet_path = os.path.join(
    os.path.expanduser("~/data-science-bp"), f"Wallet_{database_name}.zip"
)

connection.import_wallet(wallet_path=wallet_path, key=database_name)

# %%
# build the uri (this way we don't show the pwd)
connection_uri = (
    f"oracle+cx_oracle://{repo['username']}:{repo['password']}@{database_name}"
)

# %%
# !export TNS_ADMIN="/home/datascience/data-science-bp"

# %%
# %load_ext sql
# %sql $connection_uri

# %%
# %%sql result <<
# select * from DEMO1.CUSTOMERS where cust_gender = 'M'
# Out:
#  * oracle+cx_oracle://DEMO1:***@dbtst1_medium
# 0 rows affected.
# Returning data to local variable result

# %%
# creo un Pandas DataFrame
result_df = result.DataFrame()

# %%
result_df.head()
# Out:
#    cust_id cust_first_name cust_last_name cust_gender  cust_year_of_birth  \
# 0    49671         Abigail          Ruddy           M                1976
# 1     3228         Abigail          Ruddy           M                1964
# 2     6783         Abigail          Ruddy           M                1942
# 3    10338         Abigail          Ruddy           M                1977
# 4    13894         Abigail          Ruddy           M                1949
#
#   cust_marital_status           cust_street_address cust_postal_code  \
# 0             married  27 North Sagadahoc Boulevard            60332
# 1                None         37 West Geneva Street            55406
# 2              single              47 Toa Alta Road            34077
# 3             married         47 South Kanabec Road            72996
# 4                None            57 North 3rd Drive            67644
#
#       cust_city  cust_city_id  ... cust_main_phone_number  \
# 0           Ede         51442  ...           519-236-6123
# 1     Hoofddorp         51669  ...           327-194-5008
# 2     Schimmert         52297  ...           288-613-9676
# 3  Scheveningen         52296  ...           222-269-1259
# 4     Joinville         51698  ...           675-133-2226
#
#       cust_income_level  cust_credit_limit                 cust_email  \
# 0  G: 130,000 - 149,999               1500  Ruddy@company.example.com
# 1  G: 130,000 - 149,999               7000  Ruddy@company.example.com
# 2  G: 130,000 - 149,999              11000  Ruddy@company.example.com
# 3  G: 130,000 - 149,999               1500  Ruddy@company.example.com
# 4  G: 130,000 - 149,999               9000  Ruddy@company.example.com
#
#        cust_total  cust_total_id cust_src_id cust_eff_from  cust_eff_to  \
# 0  Customer total          52772        None    1998-01-01         None
# 1  Customer total          52772        None    1998-01-01         None
# 2  Customer total          52772        None    1998-01-01         None
# 3  Customer total          52772        None    1998-01-01         None
# 4  Customer total          52772        None    1998-01-01         None
#
#   cust_valid
# 0          I
# 1          A
# 2          I
# 3          I
# 4          I
#
# [5 rows x 23 columns]

# %%
# se voglio eseguire direttamente la query e mostrare il risultato
# %sql select * from DEMO1.CUSTOMERS where cust_gender = 'M' and rownum < 10
# Out:
#  * oracle+cx_oracle://DEMO1:***@dbtst1_medium
# 0 rows affected.
# [(49671, 'Abigail', 'Ruddy', 'M', 1976, 'married', '27 North Sagadahoc Boulevard', '60332', 'Ede', 51442, 'Gelderland', 52610, 52770, '519-236-6123', 'G: 130,000 - 149,999', 1500, 'Ruddy@company.example.com', 'Customer total', 52772, None, datetime.datetime(1998, 1, 1, 0, 0), None, 'I'),
#  (3228, 'Abigail', 'Ruddy', 'M', 1964, None, '37 West Geneva Street', '55406', 'Hoofddorp', 51669, 'Noord-Holland', 52683, 52770, '327-194-5008', 'G: 130,000 - 149,999', 7000, 'Ruddy@company.example.com', 'Customer total', 52772, None, datetime.datetime(1998, 1, 1, 0, 0), None, 'A'),
#  (6783, 'Abigail', 'Ruddy', 'M', 1942, 'single', '47 Toa Alta Road', '34077', 'Schimmert', 52297, 'Limburg', 52646, 52770, '288-613-9676', 'G: 130,000 - 149,999', 11000, 'Ruddy@company.example.com', 'Customer total', 52772, None, datetime.datetime(1998, 1, 1, 0, 0), None, 'I'),
#  (10338, 'Abigail', 'Ruddy', 'M', 1977, 'married', '47 South Kanabec Road', '72996', 'Scheveningen', 52296, 'Zuid-Holland', 52771, 52770, '222-269-1259', 'G: 130,000 - 149,999', 1500, 'Ruddy@company.example.com', 'Customer total', 52772, None, datetime.datetime(1998, 1, 1, 0, 0), None, 'I'),
#  (13894, 'Abigail', 'Ruddy', 'M', 1949, None, '57 North 3rd Drive', '67644', 'Joinville', 51698, 'Santa Catarina', 52734, 52775, '675-133-2226', 'G: 130,000 - 149,999', 9000, 'Ruddy@company.example.com', 'Customer total', 52772, None, datetime.datetime(1998, 1, 1, 0, 0), None, 'I'),
#  (17449, 'Abigail', 'Ruddy', 'M', 1950, 'single', '67 East Mcintosh Avenue', '83786', 'Nagoya', 51971, 'Aichi', 52543, 52782, '183-207-2933', 'G: 130,000 - 149,999', 9000, 'Ruddy@company.example.com', 'Customer total', 52772, None, datetime.datetime(1998, 1, 1, 0, 0), None, 'A'),
#  (21005, 'Abigail', 'Ruddy', 'M', 1946, 'married', '77 Bradford Avenue', '52773', 'Santos', 52293, 'Sao Paulo', 52735, 52775, '129-379-7148', 'G: 130,000 - 149,999', 3000, 'Ruddy@company.example.com', 'Customer total', 52772, None, datetime.datetime(1998, 1, 1, 0, 0), None, 'I'),
#  (24561, 'Abigail', 'Ruddy', 'M', 1978, None, '77 North Packard Avenue', '37400', 'Yokohama', 52526, 'Kanagawa', 52634, 52782, '689-236-7611', 'G: 130,000 - 149,999', 7000, 'Ruddy@company.example.com', 'Customer total', 52772, None, datetime.datetime(1998, 1, 1, 0, 0), None, 'A'),
#  (28116, 'Abigail', 'Ruddy', 'M', 1949, 'single', '87 West Coshocton Avenue', '71349', 'Haarlem', 51644, 'Noord-Holland', 52683, 52770, '208-194-6025', 'G: 130,000 - 149,999', 11000, 'Ruddy@company.example.com', 'Customer total', 52772, None, datetime.datetime(1998, 1, 1, 0, 0), None, 'I')]
