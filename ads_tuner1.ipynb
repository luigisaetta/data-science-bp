# %% [markdown]
# ### ADS Tuner for HPO
#
# A first example, using Breast Cancer Dataset

# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_breast_cancer

from ads.hpo.search_cv import ADSTuner
from ads.hpo.stopping_criterion import *
from ads.hpo.distributions import *

# %%
cancer = load_breast_cancer()

# load in Pandas DataFrame
df = pd.DataFrame(np.c_[cancer['data'], cancer['target']],
                  columns= np.append(cancer['feature_names'], ['target']))

# %%
df.columns
# Out:
# Index(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error', 'fractal dimension error',
#        'worst radius', 'worst texture', 'worst perimeter', 'worst area',
#        'worst smoothness', 'worst compactness', 'worst concavity',
#        'worst concave points', 'worst symmetry', 'worst fractal dimension',
#        'target'],
#       dtype='object')

# %%
TARGET = 'target'

# let's choose some of the column
FEATURES = ['mean radius', 'mean concavity', 'mean symmetry', 'mean fractal dimension']

X = df[FEATURES].values
y = df[TARGET].values

# %%
# train, test split
# we will be using CV
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
print('# of samples in train set', X_train.shape[0])
print('# of samples in test set', X_test.shape[0])
# Out:
# # of samples in train set 455
# # of samples in test set 114

# %% [markdown]
# ### Using Random Forest we're developing a classifier to predict target
# we will be using ADSTuner to get the best value for max_depth

# %%
clf = RandomForestClassifier(random_state=0)

tuner = ADSTuner(clf, cv=5, n_jobs=-1)

# execution by default is async
tuner.tune(X_train, y_train, exit_criterion=[TimeBudget(120)])

# %%
# this is a Pandas DataFrame
tuner.trials.head(10)
# Out:
#    number value             datetime_start datetime_complete duration  \
# 0       0  None 2022-01-31 17:29:53.213908              None     None
# 1       1  None 2022-01-31 17:29:53.232829              None     None
# 2       2  None 2022-01-31 17:29:53.263978              None     None
# 3       3  None 2022-01-31 17:29:53.284779              None     None
# 4       4  None 2022-01-31 17:29:53.307060              None     None
# 5       5  None 2022-01-31 17:29:53.306187              None     None
# 6       6  None 2022-01-31 17:29:53.338421              None     None
# 7       7  None 2022-01-31 17:29:53.359430              None     None
# 8       8  None 2022-01-31 17:29:53.390919              None     None
# 9       9  None 2022-01-31 17:29:53.412411              None     None
#
#    params_max_depth params_max_features  params_n_estimators  \
# 0                 1                log2                  163
# 1                 5                log2                  214
# 2                 1                log2                   76
# 3                 4                sqrt                  243
# 4                 1                sqrt                  175
# 5                 3                log2                  243
# 6                 2                log2                  174
# 7                 3                log2                  190
# 8                 2                log2                  218
# 9                 4                log2                  137
#
#    user_attrs_mean_fit_time  user_attrs_mean_score_time  ...  \
# 0                       NaN                         NaN  ...
# 1                       NaN                         NaN  ...
# 2                  3.847023                         NaN  ...
# 3                       NaN                         NaN  ...
# 4                       NaN                         NaN  ...
# 5                       NaN                         NaN  ...
# 6                       NaN                         NaN  ...
# 7                       NaN                         NaN  ...
# 8                       NaN                         NaN  ...
# 9                       NaN                         NaN  ...
#
#    user_attrs_metric user_attrs_split0_test_score  \
# 0                NaN                          NaN
# 1                NaN                          NaN
# 2      mean accuracy                          NaN
# 3                NaN                          NaN
# 4                NaN                          NaN
# 5                NaN                          NaN
# 6                NaN                          NaN
# 7                NaN                          NaN
# 8                NaN                          NaN
# 9                NaN                          NaN
#
#    user_attrs_split1_test_score  user_attrs_split2_test_score  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
# 5                           NaN                           NaN
# 6                           NaN                           NaN
# 7                           NaN                           NaN
# 8                           NaN                           NaN
# 9                           NaN                           NaN
#
#    user_attrs_split3_test_score  user_attrs_split4_test_score  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
# 5                           NaN                           NaN
# 6                           NaN                           NaN
# 7                           NaN                           NaN
# 8                           NaN                           NaN
# 9                           NaN                           NaN
#
#    user_attrs_std_fit_time  user_attrs_std_score_time  \
# 0                      NaN                        NaN
# 1                      NaN                        NaN
# 2                 0.852089                        NaN
# 3                      NaN                        NaN
# 4                      NaN                        NaN
# 5                      NaN                        NaN
# 6                      NaN                        NaN
# 7                      NaN                        NaN
# 8                      NaN                        NaN
# 9                      NaN                        NaN
#
#    user_attrs_std_test_score    state
# 0                        NaN  RUNNING
# 1                        NaN  RUNNING
# 2                        NaN  RUNNING
# 3                        NaN  RUNNING
# 4                        NaN  RUNNING
# 5                        NaN  RUNNING
# 6                        NaN  RUNNING
# 7                        NaN  RUNNING
# 8                        NaN  RUNNING
# 9                        NaN  RUNNING
#
# [10 rows x 21 columns]

# %%
tuner.best_score
# Out:
# 0.90989010989011

# %%
# we have not specified a strategy. If we want to limit the parameters we're changing... we need a strategy
tuner.best_params
# Out:
# {'max_depth': 4, 'max_features': 'log2', 'n_estimators': 113}

# %%
# il plot è aggiornato in maniera asincrona
tuner.plot_best_scores()
